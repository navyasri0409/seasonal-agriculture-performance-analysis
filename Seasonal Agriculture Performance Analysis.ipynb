# %%
# 🌾 Seasonal Agriculture Performance Analysis

### VOIS AICTE Batch 1 2026-2027

**Major Project**

This project analyzes agricultural performance across different seasons, geographical areas, crops, environmental conditions, resource usage, and economic factors.

The objective is to identify meaningful seasonal patterns, trends, relationships, variations, and data-driven insights that can support better agricultural planning.

# %%
# Import required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# Plot style
sns.set_style("whitegrid")

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load the dataset

df = pd.read_csv('/content/seasonal_agriculture_performance_dataset.csv')

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
# Display the first 5 rows

df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  Soil_pH  \
# 0        486.4               24.3          69.1                 5.8     7.14
# 1        855.4               25.7          78.4                 5.1     5.20
# 2        455.6               23.9          56.4                10.3     5.82
# 3        753.2               29.7          65.2                 6.3     5.98
# 4        101.6               34.1          55.2                 6.5     6.90
#
# ...

# %%
# Display the last 5 rows

df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# 3995        865.4               27.3          51.4                 6.3
# 3996        947.5               29.2          85.5                 6.1
# 3997         80.0               35.4          68.5                 8.6
# 3998        475.0               28.2          61.7                 6.4
# 3999        984.3               25.8          77.2                 5.9
#
#       Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  Phosphorus_kg_ha  \
# ...

# %%
# Check number of rows and columns

df.shape
# Out:
# (4000, 28)

# %%
# Display all column names

df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='object')

# %%
# Get information about the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   object
#  1   State                          4000 non-null   object
#  2   District                       4000 non-null   object
#  3   Crop                           4000 non-null   object
#  4   Season                         4000 non-null   object
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
# Statistical summary of numerical columns

df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %%
# Statistical summary including categorical columns

df.describe(include='all')
# Out:
#         Farm_ID           State  District  Crop  Season  Farm_Area_Hectares  \
# count      4000            4000      4000  4000    4000         4000.000000
# unique     4000               8        10     8       3                 NaN
# top     SF13961  Andhra Pradesh  Ludhiana  Rice  Kharif                 NaN
# freq          1             529       427   690    1779                 NaN
# mean        NaN             NaN       NaN   NaN     NaN            7.888265
# std         NaN             NaN       NaN   NaN     NaN            4.223764
# min         NaN             NaN       NaN   NaN     NaN            0.500000
# 25%         NaN             NaN       NaN   NaN     NaN            4.260000
# 50%         NaN             NaN       NaN   NaN     NaN            7.895000
# 75%         NaN             NaN       NaN   NaN     NaN           11.650000
# max         NaN             NaN       NaN   NaN     NaN           15.000000
#
# ...

# %%
# Check missing values in each column

missing_values = df.isnull().sum()

missing_values
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
# Check number of duplicate rows

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check missing values in each column

missing_values = df.isnull().sum()

missing_values
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
# Handle missing values using median imputation

df['Rainfall_mm'] = df['Rainfall_mm'].fillna(df['Rainfall_mm'].median())

df['Soil_Moisture_pct'] = df['Soil_Moisture_pct'].fillna(
    df['Soil_Moisture_pct'].median()
)

df['Yield_Tonnes_Ha'] = df['Yield_Tonnes_Ha'].fillna(
    df['Yield_Tonnes_Ha'].median()
)

print("Missing values handled successfully!")
# Out:
# Missing values handled successfully!

# %%
# Verify that no missing values remain

df.isnull().sum()
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
# Check data types of all columns

df.dtypes
# Out:
# Farm_ID                           object
# State                             object
# District                          object
# Crop                              object
# Season                            object
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                 object
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
# Identify numerical and categorical columns

numerical_columns = df.select_dtypes(include=np.number).columns
categorical_columns = df.select_dtypes(include='object').columns

print("Numerical Columns:")
print(list(numerical_columns))

print("\nCategorical Columns:")
print(list(categorical_columns))
# Out:
# Numerical Columns:
# ['Farm_Area_Hectares', 'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct', 'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha', 'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score', 'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne', 'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3', 'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct']
#
# Categorical Columns:
# ['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Irrigation_Method']

# %%
# Check unique values in important categorical columns

for column in categorical_columns:
    print(f"\n{column}:")
    print(df[column].nunique(), "unique values")
    print(df[column].unique()[:20])
# Out:
# Farm_ID:
# 4000 unique values
# ['SF10001' 'SF10002' 'SF10003' 'SF10004' 'SF10005' 'SF10006' 'SF10007'
#  'SF10008' 'SF10009' 'SF10010' 'SF10011' 'SF10012' 'SF10013' 'SF10014'
#  'SF10015' 'SF10016' 'SF10017' 'SF10018' 'SF10019' 'SF10020']
#
# State:
# 8 unique values
# ['Andhra Pradesh' 'Maharashtra' 'Telangana' 'Karnataka' 'Gujarat'
#  'Tamil Nadu' 'Punjab' 'Madhya Pradesh']
#
# District:
# 10 unique values
# ['Rajkot' 'Nalgonda' 'Warangal' 'Indore' 'Ludhiana' 'Raichur' 'Guntur'
#  'Krishna' 'Nashik' 'Erode']
#
# Crop:
# 8 unique values
# ['Wheat' 'Maize' 'Pulses' 'Rice' 'Cotton' 'Chilli' 'Groundnut' 'Sugarcane']
#
# Season:
# 3 unique values
# ['Kharif' 'Rabi' 'Zaid']
#
# Irrigation_Method:
# 4 unique values
# ['Drip' 'Flood' 'Rainfed' 'Sprinkler']

# %%
# Basic dataset summary

print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
print("Duplicate Rows:", df.duplicated().sum())
print("Total Missing Values:", df.isnull().sum().sum())
# Out:
# Number of Rows: 4000
# Number of Columns: 28
# Duplicate Rows: 0
# Total Missing Values: 0

# %%
# Statistical summary of numerical variables

df.describe().T
# Out:
#                                 count           mean            std  \
# Farm_Area_Hectares             4000.0       7.888265       4.223764
# Rainfall_mm                    4000.0     600.922825     287.193381
# Avg_Temperature_C              4000.0      26.818900       3.818180
# Humidity_pct                   4000.0      63.210500      11.960834
# Sunlight_Hours_Day             4000.0       7.323050       1.121186
# Soil_pH                        4000.0       6.701010       0.641461
# Soil_Moisture_pct              4000.0      26.507150       6.678837
# Nitrogen_kg_ha                 4000.0     120.250825      31.216452
# Phosphorus_kg_ha               4000.0      57.781850      17.015074
# Potassium_kg_ha                4000.0     104.760050      27.742681
# Fertilizer_kg_ha               4000.0     186.036000      60.260583
# Pesticide_Litre_ha             4000.0       5.070935       1.978879
# Seed_Quality_Score             4000.0       0.826138       0.101747
# ...

# %%
# Distribution of Crop Yield

plt.figure(figsize=(10, 6))

sns.histplot(df['Yield_Tonnes_Ha'], bins=30, kde=True)

plt.title('Distribution of Crop Yield')
plt.xlabel('Yield (Tonnes per Hectare)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Distribution of Farm Profit

plt.figure(figsize=(10, 6))

sns.histplot(df['Profit_INR'], bins=30, kde=True)

plt.title('Distribution of Farm Profit')
plt.xlabel('Profit (INR)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Distribution of Rainfall

plt.figure(figsize=(10, 6))

sns.histplot(df['Rainfall_mm'], bins=30, kde=True)

plt.title('Distribution of Rainfall')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Count the number of farms/records in each season

season_count = df['Season'].value_counts()

season_count
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
# Visualize number of records by season

plt.figure(figsize=(8, 5))

season_count.plot(kind='bar')

plt.title('Number of Records by Season')
plt.xlabel('Season')
plt.ylabel('Number of Records')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate average yield for each season

season_yield = (
    df.groupby('Season')['Yield_Tonnes_Ha']
    .mean()
    .sort_values(ascending=False)
)

season_yield
# Out:
# Season
# Kharif    5.628612
# Rabi      5.039435
# Zaid      4.641313
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Visualize average yield by season

plt.figure(figsize=(8, 5))

season_yield.plot(kind='bar')

plt.title('Average Crop Yield by Season')
plt.xlabel('Season')
plt.ylabel('Average Yield (Tonnes per Hectare)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate total production by season

season_production = (
    df.groupby('Season')['Production_Tonnes']
    .sum()
    .sort_values(ascending=False)
)

season_production
# Out:
# Season
# Kharif    82387.61
# Rabi      67498.88
# Zaid      23098.35
# Name: Production_Tonnes, dtype: float64

# %%
# Visualize total production by season

plt.figure(figsize=(8, 5))

season_production.plot(kind='bar')

plt.title('Total Crop Production by Season')
plt.xlabel('Season')
plt.ylabel('Total Production (Tonnes)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate average production by season

avg_production = (
    df.groupby('Season')['Production_Tonnes']
    .mean()
    .sort_values(ascending=False)
)

avg_production
# Out:
# Season
# Kharif    46.311192
# Rabi      41.486712
# Zaid      38.886111
# Name: Production_Tonnes, dtype: float64

# %%
# Visualize average production by season

plt.figure(figsize=(8, 5))

avg_production.plot(kind='bar')

plt.title('Average Production per Farm by Season')
plt.xlabel('Season')
plt.ylabel('Average Production (Tonnes)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate average revenue by season

season_revenue = (
    df.groupby('Season')['Revenue_INR']
    .mean()
    .sort_values(ascending=False)
)

season_revenue
# Out:
# Season
# Kharif    710719.055649
# Rabi      601526.048556
# Zaid      519171.904040
# Name: Revenue_INR, dtype: float64

# %%
# Visualize average revenue by season

plt.figure(figsize=(8, 5))

season_revenue.plot(kind='bar')

plt.title('Average Revenue by Season')
plt.xlabel('Season')
plt.ylabel('Average Revenue (INR)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate average profit by season

season_profit = (
    df.groupby('Season')['Profit_INR']
    .mean()
    .sort_values(ascending=False)
)

season_profit
# Out:
# Season
# Kharif    178914.647555
# Rabi       87689.470191
# Zaid      -24804.824916
# Name: Profit_INR, dtype: float64

# %%
# Visualize average profit by season

plt.figure(figsize=(8, 5))

season_profit.plot(kind='bar')

plt.title('Average Profit by Season')
plt.xlabel('Season')
plt.ylabel('Average Profit (INR)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Calculate average environmental conditions by season

environmental_summary = (
    df.groupby('Season')[
        [
            'Rainfall_mm',
            'Avg_Temperature_C',
            'Humidity_pct',
            'Sunlight_Hours_Day',
            'Soil_Moisture_pct'
        ]
    ]
    .mean()
    .round(2)
)

environmental_summary
# Out:
#         Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  \
# Season
# Kharif       849.20              28.45         71.81                6.79
# Rabi         437.62              23.49         57.89                7.59
# Zaid         304.65              31.04         52.01                8.18
#
#         Soil_Moisture_pct
# Season
# Kharif              31.15
# Rabi                24.07
# Zaid                19.28

# %%
# Average rainfall by season

season_rainfall = (
    df.groupby('Season')['Rainfall_mm']
    .mean()
    .sort_values(ascending=False)
)

plt.figure(figsize=(8, 5))

season_rainfall.plot(kind='bar')

plt.title('Average Rainfall by Season')
plt.xlabel('Season')
plt.ylabel('Average Rainfall (mm)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Average temperature by season

season_temperature = (
    df.groupby('Season')['Avg_Temperature_C']
    .mean()
    .sort_values(ascending=False)
)

plt.figure(figsize=(8, 5))

season_temperature.plot(kind='bar')

plt.title('Average Temperature by Season')
plt.xlabel('Season')
plt.ylabel('Average Temperature (°C)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Average water usage by season

season_water = (
    df.groupby('Season')['Water_Used_m3']
    .mean()
    .sort_values(ascending=False)
)

season_water
# Out:
# Season
# Zaid      6419.893939
# Kharif    6102.201237
# Rabi      5846.987093
# Name: Water_Used_m3, dtype: float64

# %%
# Visualize average water usage by season

plt.figure(figsize=(8, 5))

season_water.plot(kind='bar')

plt.title('Average Water Usage by Season')
plt.xlabel('Season')
plt.ylabel('Average Water Used (m³)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Relationship between rainfall and crop yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Rainfall_mm',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Rainfall vs Crop Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Relationship between temperature and crop yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Avg_Temperature_C',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Temperature vs Crop Yield')
plt.xlabel('Average Temperature (°C)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Relationship between soil moisture and crop yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Soil_Moisture_pct',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Soil Moisture vs Crop Yield')
plt.xlabel('Soil Moisture (%)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Relationship between sunlight and crop yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Sunlight_Hours_Day',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Sunlight vs Crop Yield')
plt.xlabel('Sunlight Hours per Day')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Calculate correlations with crop yield

yield_correlations = (
    df.select_dtypes(include=np.number)
    .corr()['Yield_Tonnes_Ha']
    .sort_values(ascending=False)
)

yield_correlations
# Out:
# Yield_Tonnes_Ha                  1.000000
# Water_Efficiency_t_per_1000m3    0.912568
# Production_Tonnes                0.882813
# Profit_INR                       0.488466
# Revenue_INR                      0.432152
# Water_Used_m3                    0.386294
# Nitrogen_kg_ha                   0.053149
# Phosphorus_kg_ha                 0.047941
# Rainfall_mm                      0.030951
# Total_Cost_INR                   0.030622
# Farm_Area_Hectares               0.030203
# Disease_Pest_Risk_pct            0.014292
# Humidity_pct                     0.012297
# Soil_Moisture_pct                0.010999
# Avg_Temperature_C                0.009996
# Potassium_kg_ha                  0.003382
# Fertilizer_kg_ha                 0.000018
# Seed_Quality_Score              -0.007209
# Pesticide_Litre_ha              -0.007779
# Sunlight_Hours_Day              -0.015341
# Soil_pH                         -0.020672
# Market_Price_INR_Tonne          -0.382607
# ...

# %%
# Visualize correlations with crop yield

yield_correlations = yield_correlations.drop('Yield_Tonnes_Ha')

plt.figure(figsize=(10, 7))

yield_correlations.sort_values().plot(kind='barh')

plt.title('Correlation of Agricultural Factors with Crop Yield')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Agricultural Factor')

plt.tight_layout()
plt.show()

# %%
# Fertilizer usage vs crop yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Fertilizer_kg_ha',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Fertilizer Usage vs Crop Yield')
plt.xlabel('Fertilizer (kg/ha)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Pesticide usage vs crop yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Pesticide_Litre_ha',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Pesticide Usage vs Crop Yield')
plt.xlabel('Pesticide (Litre/ha)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Average water efficiency by season

water_efficiency = (
    df.groupby('Season')['Water_Efficiency_t_per_1000m3']
    .mean()
    .sort_values(ascending=False)
)

water_efficiency
# Out:
# Season
# Kharif    5.891834
# Rabi      5.186122
# Zaid      4.413239
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
# Visualize water efficiency by season

plt.figure(figsize=(8, 5))

water_efficiency.plot(kind='bar')

plt.title('Average Water Efficiency by Season')
plt.xlabel('Season')
plt.ylabel('Water Efficiency (Tonnes per 1000 m³)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Average yield by irrigation method

irrigation_yield = (
    df.groupby('Irrigation_Method')['Yield_Tonnes_Ha']
    .mean()
    .sort_values(ascending=False)
)

irrigation_yield
# Out:
# Irrigation_Method
# Drip         6.577989
# Sprinkler    5.160627
# Flood        4.863977
# Rainfed      4.602142
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Visualize average yield by irrigation method

plt.figure(figsize=(10, 6))

irrigation_yield.plot(kind='bar')

plt.title('Average Crop Yield by Irrigation Method')
plt.xlabel('Irrigation Method')
plt.ylabel('Average Yield (Tonnes per Hectare)')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Count records for each crop

crop_count = df['Crop'].value_counts()

crop_count
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
# Visualize the top 10 crops by number of records

top_crops = crop_count.head(10)

plt.figure(figsize=(10, 6))

top_crops.plot(kind='bar')

plt.title('Top 10 Crops by Number of Records')
plt.xlabel('Crop')
plt.ylabel('Number of Records')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate average yield by crop

crop_yield = (
    df.groupby('Crop')['Yield_Tonnes_Ha']
    .mean()
    .sort_values(ascending=False)
)

crop_yield
# Out:
# Crop
# Sugarcane    46.642361
# Maize         2.710036
# Rice          2.431304
# Wheat         2.108013
# Chilli        1.542767
# Groundnut     1.322901
# Cotton        1.229783
# Pulses        0.921512
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Calculate average yield by crop

crop_yield = (
    df.groupby('Crop')['Yield_Tonnes_Ha']
    .mean()
    .sort_values(ascending=False)
)

crop_yield
# Out:
# Crop
# Sugarcane    46.642361
# Maize         2.710036
# Rice          2.431304
# Wheat         2.108013
# Chilli        1.542767
# Groundnut     1.322901
# Cotton        1.229783
# Pulses        0.921512
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Visualize top 10 crops by average yield

top_crop_yield = crop_yield.head(10)

plt.figure(figsize=(10, 6))

top_crop_yield.plot(kind='bar')

plt.title('Top 10 Crops by Average Yield')
plt.xlabel('Crop')
plt.ylabel('Average Yield (Tonnes per Hectare)')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate average profit by crop

crop_profit = (
    df.groupby('Crop')['Profit_INR']
    .mean()
    .sort_values(ascending=False)
)

crop_profit
# Out:
# Crop
# Sugarcane    817187.986885
# Chilli       750878.342233
# Cotton       124546.915354
# Groundnut     44858.120283
# Pulses        -4238.052419
# Maize        -83978.326679
# Rice        -102213.504348
# Wheat       -123398.337134
# Name: Profit_INR, dtype: float64

# %%
# Visualize top 10 crops by average profit

top_crop_profit = crop_profit.head(10)

plt.figure(figsize=(10, 6))

top_crop_profit.plot(kind='bar')

plt.title('Top 10 Crops by Average Profit')
plt.xlabel('Crop')
plt.ylabel('Average Profit (INR)')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Count crop records across different seasons

crop_season = pd.crosstab(
    df['Crop'],
    df['Season']
)

crop_season
# Out:
# Season     Kharif  Rabi  Zaid
# Crop
# Chilli        185   163    64
# Cotton        215   201    92
# Groundnut     193   177    54
# Maize         234   233    84
# Pulses        221   213    62
# Rice          314   274   102
# Sugarcane     125   129    51
# Wheat         292   237    85

# %%
# Top 10 crops across seasons

top_10_crops = df['Crop'].value_counts().head(10).index

crop_season_top = crop_season.loc[top_10_crops]

plt.figure(figsize=(12, 7))

crop_season_top.plot(kind='bar')

plt.title('Top 10 Crops Across Different Seasons')
plt.xlabel('Crop')
plt.ylabel('Number of Records')

plt.xticks(rotation=45, ha='right')
plt.legend(title='Season')

plt.tight_layout()
plt.show()

# %%
# Number of records by state

state_count = df['State'].value_counts()

state_count
# Out:
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64

# %%
# Visualize records by state

plt.figure(figsize=(12, 6))

state_count.plot(kind='bar')

plt.title('Number of Agricultural Records by State')
plt.xlabel('State')
plt.ylabel('Number of Records')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate average yield by state

state_yield = (
    df.groupby('State')['Yield_Tonnes_Ha']
    .mean()
    .sort_values(ascending=False)
)

state_yield
# Out:
# State
# Punjab            6.121116
# Karnataka         5.685481
# Gujarat           5.659016
# Telangana         5.044477
# Maharashtra       5.017480
# Madhya Pradesh    4.989940
# Tamil Nadu        4.875175
# Andhra Pradesh    4.628771
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Visualize average yield by state

plt.figure(figsize=(12, 6))

state_yield.plot(kind='bar')

plt.title('Average Crop Yield by State')
plt.xlabel('State')
plt.ylabel('Average Yield (Tonnes per Hectare)')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Calculate average yield by district

district_yield = (
    df.groupby('District')['Yield_Tonnes_Ha']
    .mean()
    .sort_values(ascending=False)
)

district_yield.head(15)
# Out:
# District
# Rajkot      6.020150
# Nalgonda    5.801181
# Ludhiana    5.799883
# Warangal    5.503389
# Guntur      5.472359
# Raichur     4.940777
# Indore      4.883240
# Nashik      4.863881
# Krishna     4.847583
# Erode       4.177816
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Top 15 districts by average yield

top_districts = district_yield.head(15)

plt.figure(figsize=(12, 7))

top_districts.sort_values().plot(kind='barh')

plt.title('Top 15 Districts by Average Crop Yield')
plt.xlabel('Average Yield (Tonnes per Hectare)')
plt.ylabel('District')

plt.tight_layout()
plt.show()

# %%
# Average yield by season and crop

season_crop_yield = (
    df.groupby(['Season', 'Crop'])['Yield_Tonnes_Ha']
    .mean()
    .round(2)
)

season_crop_yield
# Out:
# Season  Crop
# Kharif  Chilli        1.73
#         Cotton        1.37
#         Groundnut     1.48
#         Maize         2.97
#         Pulses        1.04
#         Rice          2.70
#         Sugarcane    53.46
#         Wheat         2.25
# Rabi    Chilli        1.47
#         Cotton        1.20
#         Groundnut     1.23
#         Maize         2.60
#         Pulses        0.88
#         Rice          2.32
#         Sugarcane    43.29
#         Wheat         2.06
# Zaid    Chilli        1.20
#         Cotton        0.96
#         Groundnut     1.04
#         Maize         2.29
#         Pulses        0.67
#         Rice          1.90
#         Sugarcane    38.42
#         Wheat         1.75
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Create a season vs crop yield matrix

season_crop_matrix = pd.pivot_table(
    df,
    values='Yield_Tonnes_Ha',
    index='Crop',
    columns='Season',
    aggfunc='mean'
).round(2)

season_crop_matrix
# Out:
# Season     Kharif   Rabi   Zaid
# Crop
# Chilli       1.73   1.47   1.20
# Cotton       1.37   1.20   0.96
# Groundnut    1.48   1.23   1.04
# Maize        2.97   2.60   2.29
# Pulses       1.04   0.88   0.67
# Rice         2.70   2.32   1.90
# Sugarcane   53.46  43.29  38.42
# Wheat        2.25   2.06   1.75

# %%
# Heatmap of average crop yield across seasons

plt.figure(figsize=(12, 10))

sns.heatmap(
    season_crop_matrix,
    annot=True,
    fmt='.2f',
    cmap='YlGn',
    linewidths=0.5
)

plt.title('Average Crop Yield Across Seasons')
plt.xlabel('Season')
plt.ylabel('Crop')

plt.tight_layout()
plt.show()

# %%
# Economic performance by season

economic_summary = (
    df.groupby('Season')[
        [
            'Total_Cost_INR',
            'Revenue_INR',
            'Profit_INR'
        ]
    ]
    .mean()
    .round(2)
)

economic_summary
# Out:
#         Total_Cost_INR  Revenue_INR  Profit_INR
# Season
# Kharif       531804.41    710719.06   178914.65
# Rabi         513836.58    601526.05    87689.47
# Zaid         543976.73    519171.90   -24804.82

# %%
# Calculate profit margin

df['Profit_Margin_pct'] = (
    df['Profit_INR'] / df['Revenue_INR']
) * 100

print("Profit margin calculated successfully!")
# Out:
# Profit margin calculated successfully!

# %%
# Average profit margin by season

season_profit_margin = (
    df.groupby('Season')['Profit_Margin_pct']
    .mean()
    .sort_values(ascending=False)
)

season_profit_margin
# Out:
# Season
# Kharif   -38.644541
# Rabi     -44.267645
# Zaid     -69.354573
# Name: Profit_Margin_pct, dtype: float64

# %%
# Visualize profit margin by season

plt.figure(figsize=(8, 5))

season_profit_margin.plot(kind='bar')

plt.title('Average Profit Margin by Season')
plt.xlabel('Season')
plt.ylabel('Profit Margin (%)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Create a complete seasonal performance summary

seasonal_performance = (
    df.groupby('Season')
    .agg(
        Average_Yield=('Yield_Tonnes_Ha', 'mean'),
        Average_Production=('Production_Tonnes', 'mean'),
        Average_Revenue=('Revenue_INR', 'mean'),
        Average_Cost=('Total_Cost_INR', 'mean'),
        Average_Profit=('Profit_INR', 'mean'),
        Average_Water_Used=('Water_Used_m3', 'mean'),
        Average_Water_Efficiency=(
            'Water_Efficiency_t_per_1000m3',
            'mean'
        ),
        Average_Rainfall=('Rainfall_mm', 'mean'),
        Average_Temperature=('Avg_Temperature_C', 'mean')
    )
    .round(2)
)

seasonal_performance
# Out:
#         Average_Yield  Average_Production  Average_Revenue  Average_Cost  \
# Season
# Kharif           5.63               46.31        710719.06     531804.41
# Rabi             5.04               41.49        601526.05     513836.58
# Zaid             4.64               38.89        519171.90     543976.73
#
#         Average_Profit  Average_Water_Used  Average_Water_Efficiency  \
# Season
# Kharif       178914.65             6102.20                      5.89
# Rabi          87689.47             5846.99                      5.19
# Zaid         -24804.82             6419.89                      4.41
#
#         Average_Rainfall  Average_Temperature
# Season
# Kharif            849.20                28.45
# Rabi              437.62                23.49
# Zaid              304.65                31.04

# %%
# Select important numerical variables

correlation_columns = [
    'Rainfall_mm',
    'Avg_Temperature_C',
    'Humidity_pct',
    'Sunlight_Hours_Day',
    'Soil_pH',
    'Soil_Moisture_pct',
    'Nitrogen_kg_ha',
    'Phosphorus_kg_ha',
    'Potassium_kg_ha',
    'Fertilizer_kg_ha',
    'Pesticide_Litre_ha',
    'Seed_Quality_Score',
    'Yield_Tonnes_Ha',
    'Production_Tonnes',
    'Market_Price_INR_Tonne',
    'Total_Cost_INR',
    'Revenue_INR',
    'Profit_INR',
    'Water_Used_m3',
    'Water_Efficiency_t_per_1000m3',
    'Disease_Pest_Risk_pct'
]

correlation_matrix = df[correlation_columns].corr()

# %%
# Correlation heatmap

plt.figure(figsize=(16, 12))

sns.heatmap(
    correlation_matrix,
    cmap='coolwarm',
    center=0,
    linewidths=0.5
)

plt.title('Correlation Heatmap of Agricultural Variables')

plt.tight_layout()
plt.show()

# %%
# Find variables most strongly correlated with yield

yield_relationships = (
    correlation_matrix['Yield_Tonnes_Ha']
    .drop('Yield_Tonnes_Ha')
    .sort_values(key=abs, ascending=False)
)

yield_relationships
# Out:
# Water_Efficiency_t_per_1000m3    0.912568
# Production_Tonnes                0.882813
# Profit_INR                       0.488466
# Revenue_INR                      0.432152
# Water_Used_m3                    0.386294
# Market_Price_INR_Tonne          -0.382607
# Nitrogen_kg_ha                   0.053149
# Phosphorus_kg_ha                 0.047941
# Rainfall_mm                      0.030951
# Total_Cost_INR                   0.030622
# Soil_pH                         -0.020672
# Sunlight_Hours_Day              -0.015341
# Disease_Pest_Risk_pct            0.014292
# Humidity_pct                     0.012297
# Soil_Moisture_pct                0.010999
# Avg_Temperature_C                0.009996
# Pesticide_Litre_ha              -0.007779
# Seed_Quality_Score              -0.007209
# Potassium_kg_ha                  0.003382
# Fertilizer_kg_ha                 0.000018
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
# Water Efficiency vs Crop Yield

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='Water_Efficiency_t_per_1000m3',
    y='Yield_Tonnes_Ha',
    hue='Season'
)

plt.title('Water Efficiency vs Crop Yield')
plt.xlabel('Water Efficiency (Tonnes per 1000 m³)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Water Efficiency vs Yield with trend line

plt.figure(figsize=(10, 6))

sns.regplot(
    data=df,
    x='Water_Efficiency_t_per_1000m3',
    y='Yield_Tonnes_Ha',
    scatter_kws={'alpha': 0.5},
    line_kws={}
)

plt.title('Relationship Between Water Efficiency and Crop Yield')
plt.xlabel('Water Efficiency (Tonnes per 1000 m³)')
plt.ylabel('Yield (Tonnes per Hectare)')

plt.tight_layout()
plt.show()

# %%
# Define high and low yield thresholds

low_yield_threshold = df['Yield_Tonnes_Ha'].quantile(0.25)
high_yield_threshold = df['Yield_Tonnes_Ha'].quantile(0.75)

print("Low Yield Threshold:", round(low_yield_threshold, 2))
print("High Yield Threshold:", round(high_yield_threshold, 2))
# Out:
# Low Yield Threshold: 1.05
# High Yield Threshold: 2.83

# %%
# Categorize farms based on yield

df['Yield_Performance'] = np.where(
    df['Yield_Tonnes_Ha'] >= high_yield_threshold,
    'High Yield',
    np.where(
        df['Yield_Tonnes_Ha'] <= low_yield_threshold,
        'Low Yield',
        'Medium Yield'
    )
)

df['Yield_Performance'].value_counts()
# Out:
# Yield_Performance
# Medium Yield    1989
# Low Yield       1007
# High Yield      1004
# Name: count, dtype: int64

# %%
# Compare agricultural characteristics across yield performance groups

performance_comparison = (
    df.groupby('Yield_Performance')[
        [
            'Yield_Tonnes_Ha',
            'Rainfall_mm',
            'Avg_Temperature_C',
            'Soil_Moisture_pct',
            'Fertilizer_kg_ha',
            'Water_Used_m3',
            'Water_Efficiency_t_per_1000m3',
            'Profit_INR'
        ]
    ]
    .mean()
    .round(2)
)

performance_comparison
# Out:
#                    Yield_Tonnes_Ha  Rainfall_mm  Avg_Temperature_C  \
# Yield_Performance
# High Yield                   16.66       650.33              26.84
# Low Yield                     0.64       548.97              26.85
# Medium Yield                  1.81       602.29              26.79
#
#                    Soil_Moisture_pct  Fertilizer_kg_ha  Water_Used_m3  \
# Yield_Performance
# High Yield                     27.46            187.31        9034.65
# Low Yield                      25.75            184.59        4665.06
# Medium Yield                   26.41            186.13        5235.69
#
#                    Water_Efficiency_t_per_1000m3  Profit_INR
# Yield_Performance
# High Yield                                 13.00   361130.34
# Low Yield                                   1.43  -227723.88
# Medium Yield                                3.54   157349.90

# %%
# Rank seasons based on major performance indicators

season_rankings = seasonal_performance.copy()

season_rankings['Yield_Rank'] = (
    season_rankings['Average_Yield']
    .rank(ascending=False)
)

season_rankings['Profit_Rank'] = (
    season_rankings['Average_Profit']
    .rank(ascending=False)
)

season_rankings['Water_Efficiency_Rank'] = (
    season_rankings['Average_Water_Efficiency']
    .rank(ascending=False)
)

season_rankings['Revenue_Rank'] = (
    season_rankings['Average_Revenue']
    .rank(ascending=False)
)

season_rankings.sort_values('Yield_Rank')
# Out:
#         Average_Yield  Average_Production  Average_Revenue  Average_Cost  \
# Season
# Kharif           5.63               46.31        710719.06     531804.41
# Rabi             5.04               41.49        601526.05     513836.58
# Zaid             4.64               38.89        519171.90     543976.73
#
#         Average_Profit  Average_Water_Used  Average_Water_Efficiency  \
# Season
# Kharif       178914.65             6102.20                      5.89
# Rabi          87689.47             5846.99                      5.19
# Zaid         -24804.82             6419.89                      4.41
#
#         Average_Rainfall  Average_Temperature  Yield_Rank  Profit_Rank  \
# Season
# Kharif            849.20                28.45         1.0          1.0
# Rabi              437.62                23.49         2.0          2.0
# Zaid              304.65                31.04         3.0          3.0
#
#         Water_Efficiency_Rank  Revenue_Rank
# Season
# ...

# %%
# Recreate the seasonal performance summary

season_performance = (
    df.groupby('Season')
    .agg(
        Average_Yield=('Yield_Tonnes_Ha', 'mean'),
        Average_Production=('Production_Tonnes', 'mean'),
        Average_Revenue=('Revenue_INR', 'mean'),
        Average_Cost=('Total_Cost_INR', 'mean'),
        Average_Profit=('Profit_INR', 'mean'),
        Average_Water_Used=('Water_Used_m3', 'mean'),
        Average_Water_Efficiency=(
            'Water_Efficiency_t_per_1000m3',
            'mean'
        ),
        Average_Rainfall=('Rainfall_mm', 'mean'),
        Average_Temperature=('Avg_Temperature_C', 'mean')
    )
    .round(2)
)

season_performance
# Out:
#         Average_Yield  Average_Production  Average_Revenue  Average_Cost  \
# Season
# Kharif           5.63               46.31        710719.06     531804.41
# Rabi             5.04               41.49        601526.05     513836.58
# Zaid             4.64               38.89        519171.90     543976.73
#
#         Average_Profit  Average_Water_Used  Average_Water_Efficiency  \
# Season
# Kharif       178914.65             6102.20                      5.89
# Rabi          87689.47             5846.99                      5.19
# Zaid         -24804.82             6419.89                      4.41
#
#         Average_Rainfall  Average_Temperature
# Season
# Kharif            849.20                28.45
# Rabi              437.62                23.49
# Zaid              304.65                31.04

# %%
# Identify the best-performing seasons

best_yield_season = season_performance['Average_Yield'].idxmax()

best_profit_season = season_performance['Average_Profit'].idxmax()

best_water_efficiency_season = (
    season_performance['Average_Water_Efficiency'].idxmax()
)

print("Highest Average Yield:", best_yield_season)
print("Highest Average Profit:", best_profit_season)
print("Highest Water Efficiency:", best_water_efficiency_season)
# Out:
# Highest Average Yield: Kharif
# Highest Average Profit: Kharif
# Highest Water Efficiency: Kharif

# %%
# Identify the best-performing crops

best_yield_crop = crop_yield.idxmax()
best_profit_crop = crop_profit.idxmax()

print("Highest Average Yield Crop:", best_yield_crop)
print("Highest Average Profit Crop:", best_profit_crop)
# Out:
# Highest Average Yield Crop: Sugarcane
# Highest Average Profit Crop: Sugarcane

# %%
# Identify the state with the highest average yield

best_yield_state = state_yield.idxmax()

print("Highest Average Yield State:", best_yield_state)
# Out:
# Highest Average Yield State: Punjab

# %%
# Identify the district with the highest average yield

best_yield_district = district_yield.idxmax()

print("Highest Average Yield District:", best_yield_district)
# Out:
# Highest Average Yield District: Rajkot

# %%
# Compare yield between high and low water-efficiency farms

low_efficiency = df['Water_Efficiency_t_per_1000m3'].quantile(0.25)
high_efficiency = df['Water_Efficiency_t_per_1000m3'].quantile(0.75)

low_efficiency_yield = df[
    df['Water_Efficiency_t_per_1000m3'] <= low_efficiency
]['Yield_Tonnes_Ha'].mean()

high_efficiency_yield = df[
    df['Water_Efficiency_t_per_1000m3'] >= high_efficiency
]['Yield_Tonnes_Ha'].mean()

print("Average Yield - Low Water Efficiency Farms:",
      round(low_efficiency_yield, 2))

print("Average Yield - High Water Efficiency Farms:",
      round(high_efficiency_yield, 2))
# Out:
# Average Yield - Low Water Efficiency Farms: 0.94
# Average Yield - High Water Efficiency Farms: 16.15

# %%
# Compare yield between water-efficiency groups

efficiency_comparison = pd.Series({
    'Low Water Efficiency': low_efficiency_yield,
    'High Water Efficiency': high_efficiency_yield
})

plt.figure(figsize=(8, 5))

efficiency_comparison.plot(kind='bar')

plt.title('Average Yield by Water Efficiency Level')
plt.xlabel('Water Efficiency Group')
plt.ylabel('Average Yield (Tonnes per Hectare)')

plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Top 10 highest-yield farms

top_yield_farms = (
    df.sort_values('Yield_Tonnes_Ha', ascending=False)
    [
        [
            'Farm_ID',
            'State',
            'District',
            'Crop',
            'Season',
            'Yield_Tonnes_Ha',
            'Water_Efficiency_t_per_1000m3',
            'Profit_INR'
        ]
    ]
    .head(10)
)

top_yield_farms
# Out:
#       Farm_ID           State  District       Crop  Season  Yield_Tonnes_Ha  \
# 1715  SF11716         Gujarat    Indore  Sugarcane  Kharif           101.44
# 3423  SF13424  Andhra Pradesh    Indore  Sugarcane  Kharif            95.79
# 3525  SF13526  Andhra Pradesh     Erode  Sugarcane    Rabi            93.13
# 1464  SF11465         Gujarat    Nashik  Sugarcane  Kharif            91.98
# 3523  SF13524       Karnataka    Nashik  Sugarcane  Kharif            91.46
# 2782  SF12783         Gujarat  Nalgonda  Sugarcane    Rabi            91.32
# 644   SF10645  Andhra Pradesh  Ludhiana  Sugarcane  Kharif            89.34
# 2847  SF12848       Telangana  Warangal  Sugarcane  Kharif            87.76
# 357   SF10358          Punjab  Warangal  Sugarcane    Rabi            84.75
# 1178  SF11179       Karnataka  Nalgonda  Sugarcane  Kharif            83.79
#
#       Water_Efficiency_t_per_1000m3  Profit_INR
# 1715                         54.418     1608291
# ...

# %%
# Bottom 10 lowest-yield farms

low_yield_farms = (
    df.sort_values('Yield_Tonnes_Ha', ascending=True)
    [
        [
            'Farm_ID',
            'State',
            'District',
            'Crop',
            'Season',
            'Yield_Tonnes_Ha',
            'Water_Efficiency_t_per_1000m3',
            'Profit_INR'
        ]
    ]
    .head(10)
)

low_yield_farms
# Out:
#       Farm_ID           State  District       Crop  Season  Yield_Tonnes_Ha  \
# 3670  SF13671         Gujarat  Nalgonda      Wheat  Kharif              0.3
# 3647  SF13648         Gujarat    Nashik  Groundnut  Kharif              0.3
# 2994  SF12995      Tamil Nadu     Erode       Rice    Zaid              0.3
# 2987  SF12988       Telangana    Rajkot     Pulses    Zaid              0.3
# 1135  SF11136     Maharashtra  Nalgonda  Groundnut    Rabi              0.3
# 1117  SF11118  Andhra Pradesh   Krishna     Pulses    Zaid              0.3
# 838   SF10839         Gujarat     Erode      Maize    Zaid              0.3
# 3626  SF13627       Karnataka    Guntur       Rice    Rabi              0.3
# 3619  SF13620  Madhya Pradesh     Erode     Cotton    Rabi              0.3
# 1563  SF11564          Punjab    Nashik     Cotton    Zaid              0.3
#
#       Water_Efficiency_t_per_1000m3  Profit_INR
# 3670                          1.137     -167549
# ...

# %%
# Create a summary of key project findings

key_metrics = pd.DataFrame({
    'Metric': [
        'Highest Average Yield Season',
        'Highest Average Profit Season',
        'Highest Water Efficiency Season',
        'Highest Average Yield Crop',
        'Highest Average Profit Crop',
        'Highest Average Yield State',
        'Highest Average Yield District',
        'Yield vs Water Efficiency Correlation'
    ],
    'Result': [
        best_yield_season,
        best_profit_season,
        best_water_efficiency_season,
        best_yield_crop,
        best_profit_crop,
        best_yield_state,
        best_yield_district,
        round(
            correlation_matrix.loc[
                'Yield_Tonnes_Ha',
                'Water_Efficiency_t_per_1000m3'
            ],
            3
        )
    ]
})

key_metrics
# Out:
#                                   Metric     Result
# 0           Highest Average Yield Season     Kharif
# 1          Highest Average Profit Season     Kharif
# 2        Highest Water Efficiency Season     Kharif
# 3             Highest Average Yield Crop  Sugarcane
# 4            Highest Average Profit Crop  Sugarcane
# 5            Highest Average Yield State     Punjab
# 6         Highest Average Yield District     Rajkot
# 7  Yield vs Water Efficiency Correlation      0.913
